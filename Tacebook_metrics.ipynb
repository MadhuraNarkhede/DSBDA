# %%
import pandas as pd

# %%
df=pd.read_csv('/content/dataset_Facebook.csv',sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1=df[['Page total likes','Type','Category']].loc[0:15]
df1
# Out:
#     Page total likes    Type  Category
# 0             139441   Photo         2
# 1             139441  Status         2
# 2             139441   Photo         3
# 3             139441   Photo         2
# 4             139441   Photo         2
# 5             139441  Status         2
# 6             139441   Photo         3
# 7             139441   Photo         3
# 8             139441  Status         2
# 9             139441   Photo         3
# 10            139441  Status         2
# 11            139441   Photo         2
# 12            139441   Photo         2
# 13            139441   Photo         2
# 14            138414   Photo         2
# 15            138414  Status         2

# %%
df2=df[['Page total likes','Type','Category']].loc[16:30]
df2
# Out:
#     Page total likes    Type  Category
# 16            138414   Photo         3
# 17            138414   Photo         1
# 18            138414  Status         3
# 19            138414   Photo         3
# 20            138414   Photo         2
# 21            138414   Photo         1
# 22            138414    Link         1
# 23            138414   Photo         3
# 24            138414  Status         2
# 25            138458  Status         2
# 26            138458  Status         2
# 27            138458   Photo         3
# 28            138895   Photo         2
# 29            138895   Video         1
# 30            138895   Photo         2

# %%
df3=df[['Page total likes','Type','Category']].loc[31:100]
df3
# Out:
#      Page total likes    Type  Category
# 31             138895   Photo         2
# 32             138895   Photo         3
# 33             138895   Photo         3
# 34             138895   Photo         1
# 35             138895   Photo         2
# ..                ...     ...       ...
# 96             137059   Photo         1
# 97             137059   Photo         2
# 98             137020  Status         2
# 99             137020   Photo         1
# 100            137020   Photo         1
#
# [70 rows x 3 columns]

# %%
df4=df[['Post Month','Post Weekday']].loc[0:15]
df4
# Out:
#     Post Month  Post Weekday
# 0           12             4
# 1           12             3
# 2           12             3
# 3           12             2
# 4           12             2
# 5           12             1
# 6           12             1
# 7           12             7
# 8           12             7
# 9           12             6
# 10          12             5
# 11          12             5
# 12          12             5
# 13          12             5
# 14          12             4
# 15          12             3

# %%
df5=df[['like']].loc[0:15]
df5
# Out:
#       like
# 0     79.0
# 1    130.0
# 2     66.0
# 3   1572.0
# 4    325.0
# 5    152.0
# 6    249.0
# 7    325.0
# 8    161.0
# 9    113.0
# 10   233.0
# 11    88.0
# 12    90.0
# 13   137.0
# 14   577.0
# 15    86.0

# %%
merging1=pd.concat([df1,df2,df3])
merging1
# Out:
#      Page total likes    Type  Category
# 0              139441   Photo         2
# 1              139441  Status         2
# 2              139441   Photo         3
# 3              139441   Photo         2
# 4              139441   Photo         2
# ..                ...     ...       ...
# 96             137059   Photo         1
# 97             137059   Photo         2
# 98             137020  Status         2
# 99             137020   Photo         1
# 100            137020   Photo         1
#
# [101 rows x 3 columns]

# %%
merging2=pd.concat([df4,df5],axis=1)
merging2
# Out:
#     Post Month  Post Weekday    like
# 0           12             4    79.0
# 1           12             3   130.0
# 2           12             3    66.0
# 3           12             2  1572.0
# 4           12             2   325.0
# 5           12             1   152.0
# 6           12             1   249.0
# 7           12             7   325.0
# 8           12             7   161.0
# 9           12             6   113.0
# 10          12             5   233.0
# 11          12             5    88.0
# 12          12             5    90.0
# 13          12             5   137.0
# 14          12             4   577.0
# 15          12             3    86.0

# %%
sort_values=df.sort_values('Page total likes',ascending=False)
sort_values
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 13             139441   Photo         2          12             5          3
# 1              139441  Status         2          12             3         10
# 0              139441   Photo         2          12             4          3
# 5              139441  Status         2          12             1          9
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
transposing=df.transpose()
transposing
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
pivot_table=pd.pivot_table(df,index=['Type','Category'],values='comment')

# %%
pivot_table
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714
